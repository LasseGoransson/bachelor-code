# %% [markdown]
# # Imports

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
from PIL import Image
import numpy as np
import pandas
import os
import pathlib
import datetime
import math
import sys
import optuna
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset plots

# %%
labels = !cat labelsCounts.txt

labelCount = [i.strip().split(" ") for i in labels]

x = [(i[1]) for i in labelCount]
y = [int(i[0]) for i in labelCount]

# %%
plt.rcParams['figure.figsize'] = [7.2,14.45] 
#plt.stem(x,y,use_line_collection=True)
plt.barh(x,y,0.8)
#plt.ylabel('some numbers')
#plt.ylim((0,2))
plt.yticks(rotation=0)
plt.savefig('rapport/images/labelDist.svg')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [7.2,7.45] 
#plt.stem(x,y,use_line_collection=True)
plt.table(x,y)
#plt.ylabel('some numbers')
#plt.ylim((0,2))
plt.yticks(rotation=0)
plt.savefig('rapport/images/labelDist.svg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e3092b9990e0> in <module>
#       1 plt.rcParams['figure.figsize'] = [7.2,7.45]
#       2 #plt.stem(x,y,use_line_collection=True)
# ----> 3 plt.table(x,y)
#       4 #plt.ylabel('some numbers')
#       5 #plt.ylim((0,2))
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in table(cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#    2917         colLoc='center', loc='bottom', bbox=None, edges='closed',
#    2918         **kwargs):
# -> 2919     return gca().table(
#    2920         cellText=cellText, cellColours=cellColours, cellLoc=cellLoc,
#    2921         colWidths=colWidths, rowLabels=rowLabels,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/table.py in table(ax, cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#     754     for row in cellText:
#     755         if len(row) != cols:
# --> 756             raise ValueError("Each row in 'cellText' must have {} columns"
#     757                              .format(cols))
#     758
#
# ValueError: Each row in 'cellText' must have 1 columns

# %%
#sum(y)/len(y)
min(y)
# Out:
# 3
