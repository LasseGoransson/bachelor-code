# %% [markdown]
# cd next to train and test folders

# %%
# %cd /mnt/desktop_expand/data
# Out:
# /mnt/desktop_expand/data

# %% [markdown]
# # Images per label

# %%
labels_count = !cat allTrain.csv allVal.csv | cut -d "," -f2 | sort -n | uniq -c | awk '{ print $1; }' 
labels_labels = !cat allTrain.csv allVal.csv | cut -d "," -f2 | sort -n | uniq -c | awk '{ print $2; }' 
labels = !cat allTrain.csv allVal.csv | cut -d "," -f2 

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [30, 10]



plt.stem(labels_labels,labels_count,use_line_collection=True)




plt.title('Images per label')
plt.ylabel('N')
plt.xlabel('Label')
# Out:
# Text(0.5, 0, 'Label')
